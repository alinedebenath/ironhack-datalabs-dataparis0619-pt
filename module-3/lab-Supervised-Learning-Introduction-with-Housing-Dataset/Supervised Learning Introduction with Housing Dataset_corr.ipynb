# %% [markdown]
# # Download the data

# %%
import os
import tarfile
from six.moves import urllib
import numpy as np
import seaborn as sns
from sklearn.impute import SimpleImputer

# %%
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml/master/"
HOUSING_PATH = "datasets/housing"
HOUSING_URL = DOWNLOAD_ROOT + HOUSING_PATH + "/housing.tgz"

# %%
def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()

# %%
fetch_housing_data()

# %%
import pandas as pd
def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)

# %% [markdown]
# # Take a Quick Look at the Data Structure

# %% [markdown]
# - Head
# - Info
# - Describe
# - Histogram on numerical features

# %%
# Your code
data = load_housing_data()

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC01A1DD8>,
# ...
#       dtype=object)

# %% [markdown]
# intéressant de regarder l'échelle des variables

# %%
data.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# # Create a Test Set

# %% [markdown]
# It may sound strange to voluntarily set aside part of the data at this stage. After all, you have only taken a quick glance at the data, and surely you should learn a whole lot more about it before you decide what algorithms to use, right? This is true, but your brain is an amazing pattern detection system, which means that it is highly prone to overfitting: if you look at the test set, you may stumble upon some seemingly interesting pattern in the test data that leads you to select a particular kind of Machine Learning model. When you estimate the generalization error using the test set, your estimate will be too optimistic and you will launch a system that will not perform as well as expected. This is called data snooping bias.

# %% [markdown]
# éviter de faire des overfits. Séparer déjà le test avant de faire le reste du traitement

# %%
# Your code
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(data, test_size=0.2)

# %% [markdown]
# ATTENTION: Il faut retirer les tests avant de faire toute autre modification sinon ça ne fontionne pas!!!!!!! Le reste du traitement doit être fait sur le train_set.

# %% [markdown]
# # Discover and Visualize the Data to Gain Insights

# %% [markdown]
# ## Visualizing Geographical Data

# %%
# Your code
BBox = ((data.longitude.min(),data.longitude.max(),data.latitude.min(),data.latitude.max()))
BBox
# Out:
# (-124.35, -114.31, 32.54, 41.95)

# %%
import matplotlib.pyplot as plt
map_= plt.imread('map.png')

# %%
data.plot(kind='scatter', x='longitude', y='latitude', alpha=0.4,s=data['population']/100, label='population', figsize=(10,7),c='median_house_value', cmap=plt.get_cmap('jet'), colorbar=True)


plt.imshow(map_, extent=[-124.35, -114.31, 32.54, 41.95], alpha=0.5)
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)
plt.legend() 
plt.show()

# %% [markdown]
# ## Looking for Correlations

# %%
data['median_house_value'].sort_values(ascending = True)
# Out:
# 9188      14999.0
# 19802     14999.0
# 2799      14999.0
# 2521      14999.0
# 5887      17500.0
#            ...
# 16938    500001.0
# 16936    500001.0
# 16935    500001.0
# 8291     500001.0
# 18055    500001.0
# Name: median_house_value, Length: 20640, dtype: float64

# %%
# Your code
corr = data.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)

# %% [markdown]
# ## Experimenting with Feature Engineering

# %% [markdown]
# Try to think of new features more useful than some that already exist. For example, the total number of rooms in a district is not very useful if you don’t know how many households there are.

# %%
# Your code
data["rooms_households"] = data["total_rooms"]/data["households"]

# %%
# Check the correlation with the new features
corr = data.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Variable Encoding

# %%
#Your code
data.ocean_proximity.value_counts().plot.bar()

# %%
data_dummy = pd.get_dummies(data,'ocean_proximity', drop_first=True)

# %%
data_dummy.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    rooms_households  ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 0          6.984127                       0                       0
# ...

# %% [markdown]
# ## Data Cleaning (missing values handling)

# %%
# Check a class called Imputer in Scikit Learn with parameter "median"

# %%
# Your code
data_dummy = data_dummy.fillna(data_dummy.median())

# %% [markdown]
# 1-instance
# 2-fit sur la donnée
# 3-transformer la donnée

# %%
#correction 
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='median')

# %%
data_imp = pd.DataFrame(imp.fit_transform(data_dummy), columns = data_dummy.columns)

# %%
data_dummy.head()
data_dummy.isna().sum()
# Out:
# longitude                     0
# latitude                      0
# housing_median_age            0
# total_rooms                   0
# total_bedrooms                0
# population                    0
# households                    0
# median_income                 0
# median_house_value            0
# rooms_households              0
# ocean_proximity_INLAND        0
# ocean_proximity_ISLAND        0
# ocean_proximity_NEAR BAY      0
# ocean_proximity_NEAR OCEAN    0
# dtype: int64

# %% [markdown]
# ## Feature engineering

# %%
# Add the features that you discovered before

# %% [markdown]
# # Your code
# ajout des features à data_imp
# il faudra appliquer le même traitement du training sur le test.

# %% [markdown]
# ## Feature Scaling

# %%
# Check StandardScaler in Scikit Learn
from sklearn.preprocessing import StandardScaler

# %%
# your code, correction 
#retire la moyenne de la colonne/divise par l'écart type. 
scaler = StandardScaler()
scaler.fit(data_imp)
#scaler.mean_
data_scl = pd.DataFrame(scaler.transform(data_imp), columns=data_imp.columns)

# %% [markdown]
# # Select and Train a Model

# %% [markdown]
# ## Training and Evaluating on the Training Set

# %% [markdown]
# Try :
# - Linear Regression
# - Decision Tree Regression
# - Random Forest Regression
# (check Scikit Learn)
#
#
# With Performance Metric = RMSE

# %% [markdown]
# ## Model Evaluation Using Cross-Validation

# %% [markdown]
# Check from sklearn.model_selection import cross_val_score

# %%
cols = [x for x in data_dummy.columns.values if x!= "median_house_value"]
X_train, X_test, y_train, y_test = train_test_split(data_dummy[cols], data_dummy["median_house_value"], test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

model_1 = LogisticRegression()
model_1.fit(X_train, y_train)
# Out:
# C:\Users\aline\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\aline\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\aline\AppData\Roaming\Python\Python37\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
# ...

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

y_pred = model_1.predict(X_test)
confusion_matrix(y_test, y_pred)
accuracy_score(y_test, y_pred)

# %%
#correction model 1
y_train = data['median_house_value']
X_train = data_scl.drop(columns = ['median_house_value'])
model_1 = LogisticRegression()
model_1.fit(X_train, y_train)

# %%
y_train_pred = model_1.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_train, y_train_pred))

# %% [markdown]
# #correction model 2
# à faire toute seule parce que ça va trop vite !!!

# %% [markdown]
# ##cross_val_score permet de valider ou non un model, prendre l'argument scoring a mettre en np.array puis prendre sa racine carré. On doit trouver une erreur de l'ordre de 80000$. model 2 en overfitting (parfait sur le train et mauvais sur la validation.
# model 3 = Random forest = ensemble de decision tree. En ML, ensemble de modéle apprend mieux que séparemment.

# %% [markdown]
# Evaluation du modèle:
#     Appliquer aux données du test toutes nos transformation (suppression de la variable à prédire, get_dummies, ajout des features, missing values (juste transform), scaling (juste transform), ). Il aurait été intéressant de faire des fonctions pour aller plus vite.

# %% [markdown]
# ATTENTION: Il faut retirer les tests avant de faire toute autre modification sinon ça ne fontionne pas!!!!!!!

# %% [markdown]
# sauvegarde du modèle avec joblib, joblib.dump à explorer. Si on veux le charger joblib.load.
# ensuite si nouvelle donnée on peut l'appliquer le modèle sauvegarder dessus.
