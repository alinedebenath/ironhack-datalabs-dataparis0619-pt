# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import datasets, utils
from sklearn.model_selection import cross_val_score
from sklearn import tree, pipeline, preprocessing
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.externals import joblib
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso

# %%
??pd.read_csv

# %%
chunksize = 10
chunk_enum = pd.read_csv('..\countryContinent.csv', encoding='cp1252', chunksize=chunksize)

# %%
current_df = next(chunk_enum).dropna()

# %%
current_df
# Out:
#                country code_2 code_3  country_code     iso_3166_2 continent  \
# 0          Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1        Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 2              Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3              Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 4       American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
# 5              Andorra     AD    AND            20  ISO 3166-2:AD    Europe
# 6               Angola     AO    AGO            24  ISO 3166-2:AO    Africa
# 7             Anguilla     AI    AIA           660  ISO 3166-2:AI  Americas
# 9  Antigua and Barbuda     AG    ATG            28  ISO 3166-2:AG  Americas
#
#         sub_region  region_code  sub_region_code
# 0    Southern Asia        142.0             34.0
# 1  Northern Europe        150.0            154.0
# 2  Southern Europe        150.0             39.0
# ...

# %%
lasso = Lasso(warm_start=True)

# %%
lasso.fit(np.array(current_df["region_code"]).reshape(-1, 1), current_df["sub_region_code"])
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=True)

# %%
for chunk in chunk_enum:
    current_df = chunk.dropna()
    print(chunk.head(1))
    lasso.fit(np.array(current_df["region_code"]).reshape(-1, 1), current_df["sub_region_code"])
# Out:
#       country code_2 code_3  country_code     iso_3166_2 continent  \
# 10  Argentina     AR    ARG            32  ISO 3166-2:AR  Americas
#
#        sub_region  region_code  sub_region_code
# 10  South America           19                5
#     country code_2 code_3  country_code     iso_3166_2 continent  \
# 20  Belarus     BY    BLR           112  ISO 3166-2:BY    Europe
#
#         sub_region  region_code  sub_region_code
# 20  Eastern Europe          150              151
#           country code_2 code_3  country_code     iso_3166_2 continent  \
# 30  Bouvet Island     BV    BVT            74  ISO 3166-2:BV       NaN
#
#    sub_region  region_code  sub_region_code
# 30        NaN          NaN              NaN
#        country code_2 code_3  country_code     iso_3166_2 continent  \
# 40  Cabo Verde     CV    CPV           132  ISO 3166-2:CV    Africa
#
#         sub_region  region_code  sub_region_code
# 40  Western Africa          2.0             11.0
# ...
