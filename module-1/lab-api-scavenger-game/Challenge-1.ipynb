# %%
import pandas as pd
data = pd.read_json('forks.json')
data.head()
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/orianegsx/ironhac...     False
# 1  https://api.github.com/repos/Amibam/ironhack-d...     False
# 2  https://api.github.com/repos/Daygina/ironhack-...     False
# 3  https://api.github.com/repos/stressisboucard/i...     False
# 4  https://api.github.com/repos/evitry/ironhack-d...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/orianegsx/ironhac...
# 1  https://api.github.com/repos/Amibam/ironhack-d...
# 2  https://api.github.com/repos/Daygina/ironhack-...
# 3  https://api.github.com/repos/stressisboucard/i...
# 4  https://api.github.com/repos/evitry/ironhack-d...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/orianegsx/ironhac...
# 1  https://api.github.com/repos/Amibam/ironhack-d...
# 2  https://api.github.com/repos/Daygina/ironhack-...
# ...

# %%
languages=[]
for l in data['language']:
    if l not in languages:
        languages.append(l)
languages
# Out:
# ['Jupyter Notebook']
