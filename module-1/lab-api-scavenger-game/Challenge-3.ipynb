# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

url='https://api.github.com/repos/ironhack-datalabs/scavenger/contents'
headers = {"Authorization": "token 'mytoken'"}
response = requests.get(url, headers=headers)
results = response.json()
flattened_data = json_normalize(results)
flattened_data
# Out:
#                                            _links.git  \
# 0   https://api.github.com/repos/ironhack-datalabs...
# 1   https://api.github.com/repos/ironhack-datalabs...
# 2   https://api.github.com/repos/ironhack-datalabs...
# 3   https://api.github.com/repos/ironhack-datalabs...
# 4   https://api.github.com/repos/ironhack-datalabs...
# 5   https://api.github.com/repos/ironhack-datalabs...
# 6   https://api.github.com/repos/ironhack-datalabs...
# 7   https://api.github.com/repos/ironhack-datalabs...
# 8   https://api.github.com/repos/ironhack-datalabs...
# 9   https://api.github.com/repos/ironhack-datalabs...
# 10  https://api.github.com/repos/ironhack-datalabs...
# 11  https://api.github.com/repos/ironhack-datalabs...
# 12  https://api.github.com/repos/ironhack-datalabs...
# 13  https://api.github.com/repos/ironhack-datalabs...
# 14  https://api.github.com/repos/ironhack-datalabs...
# 15  https://api.github.com/repos/ironhack-datalabs...
# ...

# %%
data_flat = pd.DataFrame()
for path in flattened_data['path']:
    url=f'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{path}'
    headers = {"Authorization":"token 'mytoken'"}
    response = requests.get(url, headers=headers)
    results = response.json()
    data1 = json_normalize(results)
    data_flat=data_flat.append(data1)
data_flat
# Out:
#                                            _links.git  \
# 0   https://api.github.com/repos/ironhack-datalabs...
# 0   https://api.github.com/repos/ironhack-datalabs...
# 1   https://api.github.com/repos/ironhack-datalabs...
# 2   https://api.github.com/repos/ironhack-datalabs...
# 3   https://api.github.com/repos/ironhack-datalabs...
# 0   https://api.github.com/repos/ironhack-datalabs...
# 1   https://api.github.com/repos/ironhack-datalabs...
# 2   https://api.github.com/repos/ironhack-datalabs...
# 3   https://api.github.com/repos/ironhack-datalabs...
# 0   https://api.github.com/repos/ironhack-datalabs...
# 1   https://api.github.com/repos/ironhack-datalabs...
# 2   https://api.github.com/repos/ironhack-datalabs...
# 0   https://api.github.com/repos/ironhack-datalabs...
# 1   https://api.github.com/repos/ironhack-datalabs...
# 2   https://api.github.com/repos/ironhack-datalabs...
# 0   https://api.github.com/repos/ironhack-datalabs...
# ...

# %%
r=requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt', headers=headers)
r
# Out:
# <Response [200]>

# %%
y=r.json()['content']
y
# Out:
# 'b2YK\n'

# %%
import base64
base64.b64decode(y)
# Out:
# b'of\n'

# %%
path_joke = []
joke=[]
for path in data_flat['path']:
    if 'scavenger' in path:
        path_joke.append(path)
        path_joke.sort(key=lambda x: x[8:11])
        URL_PATTERN = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{}'
        url = URL_PATTERN.format(path_joke)
        response = requests.get(url, headers=headers)
        results = response.json()['content']
        joke.append(results)
joke
#joke = []
#for path_ok in data_flat['path']:
    #if 'scavenger'in path_ok:
        #path_joke.append(data_flat['path'])
        #url='https://api.github.com/repos/ironhack-datalabs/scavenger/contents/'+p
        #response=requests.get(url, headers=headers)
        #results=response.json()['content']
        #joke=joke.append(results)
#joke
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-278-97fbfe090d8c> in <module>
#       9         url = URL_PATTERN.format(path_joke)
#      10         response = requests.get(url, headers=headers)
# ---> 11         results = response.json()['content']
#      12         joke.append(results)
#      13 joke
#
# KeyError: 'content'
