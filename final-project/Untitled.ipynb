# %%
import pandas as pd

# %%
data= pd.read_excel('./../../Donnees_Brutes_Declaration_Ruches_2017.xlsx', sheet_name = 2)

# %%
data.head(20)
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0         SIRET                                             (Tous)
# 1           NaN                                                NaN
# 2          TCD2  Total de colonies par nombre de colonies décla...
# 3   Département                                                  0
# 4            01                                                  0
# 5            02                                                  0
# 6            03                                                  0
# 7            04                                                  0
# 8            05                                                  0
# 9            06                                                  0
# 10           07                                                  0
# 11           08                                                  0
# 12           09                                                  0
# ...
